# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
columns = [
    "age", "sex", "cp", "trestbps", "chol", "fbs", "restecg",
    "thalach", "exang", "oldpeak", "slope", "ca", "thal", "target"
]

df = pd.read_csv('New_folder\processed.cleveland.data', names=columns)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\p'
# <>:6: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\ELGENDY\AppData\Local\Temp\ipykernel_9776\3937727530.py:6: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv('New_folder\processed.cleveland.data', names=columns)

# %%
print(df.head())
print(df.info())
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  target
# 0    3.0  0.0  6.0       0
# 1    2.0  3.0  3.0       2
# 2    2.0  2.0  7.0       1
# 3    3.0  0.0  3.0       0
# 4    1.0  0.0  3.0       0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
# ...

# %%
df.replace("?", np.nan, inplace=True)


df = df.apply(pd.to_numeric)


df.dropna(inplace=True)

df["target"] = df["target"].apply(lambda x: 1 if x > 0 else 0)

# %%
df.to_csv("data\heart_disease.csv", index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\ELGENDY\AppData\Local\Temp\ipykernel_9776\1760617390.py:1: SyntaxWarning: invalid escape sequence '\h'
#   df.to_csv("data\heart_disease.csv", index=False)

# %%
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  target
# 0    3.0  0.0   6.0       0
# 1    2.0  3.0   3.0       1
# 2    2.0  2.0   7.0       1
# 3    3.0  0.0   3.0       0
# 4    1.0  0.0   3.0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 0 to 301
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       297 non-null    float64
#  1   sex       297 non-null    float64
#  2   cp        297 non-null    float64
#  3   trestbps  297 non-null    float64
#  4   chol      297 non-null    float64
#  5   fbs       297 non-null    float64
#  6   restecg   297 non-null    float64
#  7   thalach   297 non-null    float64
#  8   exang     297 non-null    float64
#  9   oldpeak   297 non-null    float64
#  10  slope     297 non-null    float64
#  11  ca        297 non-null    float64
#  12  thal      297 non-null    float64
#  13  target    297 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 34.8 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Label Encoding
le = LabelEncoder()
df['slope'] = le.fit_transform(df['slope'])




# One-hot encoding

categorical_cols = ['cp', 'restecg','thal']
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 0 to 301
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          297 non-null    float64
#  1   sex          297 non-null    float64
#  2   trestbps     297 non-null    float64
#  3   chol         297 non-null    float64
#  4   fbs          297 non-null    float64
#  5   thalach      297 non-null    float64
#  6   exang        297 non-null    float64
#  7   oldpeak      297 non-null    float64
#  8   slope        297 non-null    int64
#  9   ca           297 non-null    float64
#  10  target       297 non-null    int64
#  11  cp_2.0       297 non-null    bool
#  12  cp_3.0       297 non-null    bool
#  13  cp_4.0       297 non-null    bool
#  14  restecg_1.0  297 non-null    bool
#  15  restecg_2.0  297 non-null    bool
#  16  thal_6.0     297 non-null    bool
#  17  thal_7.0     297 non-null    bool
# dtypes: bool(7), float64(9), int64(2)
# ...

# %%
scalable_columns = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'ca']

scaler = StandardScaler()
df[scalable_columns] = scaler.fit_transform(df[scalable_columns])

df.head()
# Out:
#         age  sex  trestbps      chol  fbs   thalach  exang   oldpeak  slope  \
# 0  0.936181  1.0  0.750380 -0.276443  1.0  0.017494    0.0  1.068965      2
# 1  1.378929  1.0  1.596266  0.744555  0.0 -1.816334    1.0  0.381773      1
# 2  1.378929  1.0 -0.659431 -0.353500  0.0 -0.899420    1.0  1.326662      1
# 3 -1.941680  1.0 -0.095506  0.051047  0.0  1.633010    0.0  2.099753      2
# 4 -1.498933  0.0 -0.095506 -0.835103  0.0  0.978071    0.0  0.295874      0
#
#          ca  target  cp_2.0  cp_3.0  cp_4.0  restecg_1.0  restecg_2.0  \
# 0 -0.721976       0   False   False   False        False         True
# 1  2.478425       1   False   False    True        False         True
# 2  1.411625       1   False   False    True        False         True
# 3 -0.721976       0   False    True   False        False        False
# 4 -0.721976       0    True   False   False        False         True
#
#    thal_6.0  thal_7.0
# 0      True     False
# 1     False     False
# ...

# %%
# Histograms for all features
df.hist(figsize=(16, 12), bins=20)
plt.suptitle('Histograms of All Features')
plt.show()

# Correlation heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# Boxplots for all features grouped by target
for col in df.columns:
    if col != 'target':
        plt.figure(figsize=(6, 4))
        sns.boxplot(x='target', y=col, data=df)
        plt.title(f'Boxplot of {col} by Target')
        plt.show()

# %%
df.to_csv("data\heart_disease_after_cleaned.csv", index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# <>:1: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\ELGENDY\AppData\Local\Temp\ipykernel_9776\3962304495.py:1: SyntaxWarning: invalid escape sequence '\h'
#   df.to_csv("data\heart_disease_after_cleaned.csv", index=False)
